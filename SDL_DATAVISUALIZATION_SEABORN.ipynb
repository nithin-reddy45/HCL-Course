# %% [markdown]
# <a href="https://colab.research.google.com/github/nithin-reddy45/HCL-Course/blob/main/SDL_DATAVISUALIZATION_SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(1)
months = pd.date_range(start="2023-01-01", periods=12, freq="M")
data_retail = pd.DataFrame({
    "Month": np.tile(months, 4),
    "Category": np.repeat(["Electronics", "Clothing", "Furniture", "Groceries"], 12),
    "Sales": np.random.randint(50, 200, 48)
})
data_retail["Quarter"] = data_retail["Month"].dt.to_period("Q")
plt.figure(figsize=(10,6))
sns.lineplot(data=data_retail, x="Month", y="Sales", hue="Category", marker="o")
plt.title("Monthly Sales Trend by Category (2023)")
plt.ylabel("Sales ( in Million $)")
plt.xlabel("Month")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\thumm\AppData\Local\Temp\ipykernel_1992\1266304069.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months = pd.date_range(start="2023-01-01", periods=12, freq="M")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)
scores = np.random.normal(loc=65, scale=15, size=200)
scores = np.clip(scores, 0, 100)
data_scores = pd.DataFrame({"Score": scores})
plt.figure(figsize=(8,5))
sns.histplot(data_scores["Score"], bins=15, kde=True, color="orange", edgecolor="black")
plt.title("Distribution of Student Math Test Scores")
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.show()
